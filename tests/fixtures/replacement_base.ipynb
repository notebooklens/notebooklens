# %% [markdown]
# # Public Park Visits — Weekly Review
#
# Synthetic weekly visit counts for public parks (sample data, not real telemetry).
#
# | Park | Visits (baseline) |
# | --- | --- |
# | Riverside | 120 |
# | Lakeside | 95 |

# %%
import pandas as pd

visits = pd.read_csv("public_park_visits.csv")

# %%
visits.groupby("park").sum().head()
# Out:
#         park  visits
# 0  Riverside     120
# 1    Lakeside      95

# %%
assert "park" in visits.columns
print("columns valid: park, visits")
# Out:
# columns valid: park, visits

# %%
plot_visits_trend(visits, color="red")

# %%
plot_visits_bar_chart(visits)
# Out:
# Figure
