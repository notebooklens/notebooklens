# %%
API_KEY = super-secret-token
DB_PASSWORD = hunter2
CONNECTION_STRING = postgresql://alice:pw123@example.com:5432/app
owner_email = sai@example.com
blob = AAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAA
# Out:
# Reach me at analyst@example.com
# token=abcd1234
# Traceback (most recent call last):
# ValueError: bad token
